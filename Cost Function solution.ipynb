# %%
import notebook
notebook.__version__
# Out:
# '7.1.3'

# %%
pip install --upgrade notebook
# Out:
# ...
#   Using cached notebook-7.1.3-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached jupyterlab-4.1.6-py3-none-any.whl.metadata (16 kB)
# ...
#   Using cached httpx-0.27.0-py3-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached httpcore-1.0.5-py3-none-any.whl.metadata (20 kB)
# ...
#   Using cached h11-0.14.0-py3-none-any.whl.metadata (8.2 kB)
# ...
# Using cached notebook-7.1.3-py3-none-any.whl (5.0 MB)
# ...
#    ---------------------------------------- 0.0/11.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/11.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/11.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/11.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/11.4 MB 1.3 MB/s eta 0:00:09
#    ---------------------------------------- 0.0/11.4 MB 1.3 MB/s eta 0:00:09
# ...

# %%
pip install lab_utils_uni
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement lab_utils_uni (from versions: none)
# ERROR: No matching distribution found for lab_utils_uni

# %%
import numpy as np
import matplotlib.pyplot as plt
from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
plt.style.use('./deeplearning.mplstyle')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 3
#       1 import numpy as np
#       2 import matplotlib.pyplot as plt
# ----> 3 from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
#       4 plt.style.use('./deeplearning.mplstyle')
#
# ModuleNotFoundError: No module named 'lab_utils_uni'

# %%
x_train = np.array([1,2])      #(size in 100 square feet)
y_train = np.array([300, 500])  # (Price in 1000s of dollars)

# %%
def compute_cost(x, y, w, b):
    """
    Comoute the cost function for linear regression

    Args:
    x (ndarray (m,)): Data, m example
    y (ndarray (m,)): target values
    w,b (scalar)    : model paramters

    Returns
        total_cost (float: The cost of using w,b as the parameters for linear regression
                to fit the data points in x and y
    """
    # niumber of training examples
    m = x.shape[0]

    cost_sum = 0
    for i in range(m):
        f_wb =w * x[i] + b
        cost = (f_wb - y[i]) ** 2
        cost_sum = cost_sum + cost
    total_cost = (1 / (2*m)) * cost_sum

    return total_cost

# %%
pit_intution(x_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 pit_intution(x_train, y_train)
#
# NameError: name 'pit_intution' is not defined
